# %% [markdown]
# # KENYA LITERACY AND EDUCATION SURVEY DATA

# %% [markdown]
# ## Background
# Literacy is a foundational component of human development and a key indicator of national progress. In Kenya, literacy levels influence access to education, employment, and healthcare outcomes. This dataset compiles national survey data from DHS and MIS programs between 2003 and 2022, offering a view of literacy across gender, age groups, and survey types.
#
# ## Objectives
# 1. To analyze literacy trends in Kenya over time using nationally representative survey data.
# 2. To compare literacy and education indicators across gender and demographic subgroups.
# 3. To identify gaps and disparities that can inform policy interventions.
#
# ## Research Questions
# 1. What are the gender disparities in literacy and education access?
# 2. How have literacy rates in Kenya evolved from 2003 to 2022?
# 3. Which indicators show the most significant improvement or decline?
# 4. How do sample sizes and survey types affect reported literacy outcomes?
#
# ## Dataset Description
# The dataset used in this analysis is the literacy_national `Data.Humdata.org`. It contains 29 records with features such as 'SurveyId','IndicatorId','IndicatorOrder','IsTotal','IsPreferred','SurveyType','DenominatorWeighted',and 'DenominatorUnweighted'. Missing values, duplicates, and outliers were addressed as Feature engineering metrics, like ratios and percentages features were added to the dataset.
#
# ## Methodology
# The analysis involves the following:
# 1. **Data Cleaning:** Handled missing values and outliers, and standardized indicator labels.
# 2. **Exploratory Analysis:** Identified key trends by creating visualization distributions such as histograms, bar graphs, and scatterplot.
# 3. **Feature Engineering:** Created calculated fields such as ratios and percentage features.
# 4. **Visualization:** Used Tableau to build dashboards including line charts, bar charts, scatterplots, and heatmaps.
#
# ## Significance
# This analysis provides a data-driven foundation for understanding literacy dynamics in Kenya. It highlights areas of progress, especially in gender equity and education access. The findings can support policymakers, educators, and development partners in designing targeted interventions that promote literacy growth.

# %% [markdown]
# ## NON-TECHNICAL
#
# 1. **PRESENTATON:[Link](https://docs.google.com/presentation/d/1tYfeW8hYOm2mpPfyo3h6oIN3X4M98GGTel7d9TJihLo/edit?usp=sharing)**
# 2. **TABLEAU:[LINK](https://public.tableau.com/app/profile/ian.moire/viz/KenyaNationalLiteracyTrends/KenyaNationalLiteracyTrends)**

# %% [markdown]
# ## Use the required libraries to open the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Open the dataset

# %%
df = pd.read_csv('/Users/mac/Documents/DATA.HUMDATA.ORG/literacy_national_ken.csv')
print(df)
# Out:
#               ISO3    DataId                                 Indicator  \
# 0    #country+code  #meta+id                           #indicator+name
# 1              KEN    419826  Women with secondary or higher education
# 2              KEN    419827       Women who can read a whole sentence
# 3              KEN    419828     Women who can read part of a sentence
# 4              KEN    419833              Women who cannot read at all
# ..             ...       ...                                       ...
# 99             KEN    230750       Men who are blind/visually impaired
# 100            KEN    230757                     Men's literacy: Total
# 101            KEN    230753                      Men who are literate
# 102            KEN    150861                             Number of men
# 103            KEN    230808                Number of men (unweighted)
#
#                     Value             Precision DHS_CountryCode  \
# 0    #indicator+value+num  #indicator+precision             NaN
# 1                    29.3                     1              KE
# 2                    42.1                     1              KE
# 3                     7.1                     1              KE
# 4                    21.2                     1              KE
# ..                    ...                   ...             ...
# 99                      0                     1              KE
# 100                   100                     1              KE
# 101                  93.8                     1              KE
# 102                 13652                     0              KE
# 103                 13669                     0              KE
#
#        CountryName  SurveyYear    SurveyId      IndicatorId  ...  IsPreferred  \
# 0    #country+name  #date+year  #survey+id  #indicator+code  ...          NaN
# 1            Kenya        2003   KE2003DHS    ED_LITR_W_SCH  ...          1.0
# 2            Kenya        2003   KE2003DHS    ED_LITR_W_RDW  ...          1.0
# 3            Kenya        2003   KE2003DHS    ED_LITR_W_RDP  ...          1.0
# 4            Kenya        2003   KE2003DHS    ED_LITR_W_NRD  ...          1.0
# ..             ...         ...         ...              ...  ...          ...
# 99           Kenya        2022   KE2022DHS    ED_LITR_M_BLD  ...          1.0
# 100          Kenya        2022   KE2022DHS    ED_LITR_M_TOT  ...          1.0
# 101          Kenya        2022   KE2022DHS    ED_LITR_M_LIT  ...          1.0
# 102          Kenya        2022   KE2022DHS    ED_LITR_M_NUM  ...          1.0
# 103          Kenya        2022   KE2022DHS    ED_LITR_M_UNW  ...          1.0
#
#           SDRID  RegionId  SurveyYearLabel SurveyType DenominatorWeighted  \
# 0           NaN       NaN              NaN        NaN                 NaN
# 1    EDLITRWSCH       NaN             2003        DHS              8195.0
# 2    EDLITRWRDW       NaN             2003        DHS              8195.0
# 3    EDLITRWRDP       NaN             2003        DHS              8195.0
# 4    EDLITRWNRD       NaN             2003        DHS              8195.0
# ..          ...       ...              ...        ...                 ...
# 99   EDLITRMBLD       NaN             2022        DHS             13652.0
# 100  EDLITRMTOT       NaN             2022        DHS             13652.0
# 101  EDLITRMLIT       NaN             2022        DHS             13652.0
# 102  EDLITRMNUM       NaN             2022        DHS                 NaN
# 103  EDLITRMUNW       NaN             2022        DHS             13652.0
#
#     DenominatorUnweighted CILow  CIHigh  LevelRank
# 0                     NaN   NaN     NaN        NaN
# 1                  8195.0   NaN     NaN        NaN
# 2                  8195.0   NaN     NaN        NaN
# 3                  8195.0   NaN     NaN        NaN
# 4                  8195.0   NaN     NaN        NaN
# ..                    ...   ...     ...        ...
# 99                13669.0   NaN     NaN        NaN
# 100               13669.0   NaN     NaN        NaN
# 101               13669.0   NaN     NaN        NaN
# 102               13669.0   NaN     NaN        NaN
# 103                   NaN   NaN     NaN        NaN
#
# [104 rows x 29 columns]

# %%
# Open the dataset to see the details
df
# Out:
#               ISO3    DataId                                 Indicator  \
# 0    #country+code  #meta+id                           #indicator+name
# 1              KEN    419826  Women with secondary or higher education
# 2              KEN    419827       Women who can read a whole sentence
# 3              KEN    419828     Women who can read part of a sentence
# 4              KEN    419833              Women who cannot read at all
# ..             ...       ...                                       ...
# 99             KEN    230750       Men who are blind/visually impaired
# 100            KEN    230757                     Men's literacy: Total
# 101            KEN    230753                      Men who are literate
# 102            KEN    150861                             Number of men
# 103            KEN    230808                Number of men (unweighted)
#
#                     Value             Precision DHS_CountryCode  \
# 0    #indicator+value+num  #indicator+precision             NaN
# 1                    29.3                     1              KE
# 2                    42.1                     1              KE
# 3                     7.1                     1              KE
# 4                    21.2                     1              KE
# ..                    ...                   ...             ...
# 99                      0                     1              KE
# 100                   100                     1              KE
# 101                  93.8                     1              KE
# 102                 13652                     0              KE
# 103                 13669                     0              KE
#
#        CountryName  SurveyYear    SurveyId      IndicatorId  ...  IsPreferred  \
# 0    #country+name  #date+year  #survey+id  #indicator+code  ...          NaN
# 1            Kenya        2003   KE2003DHS    ED_LITR_W_SCH  ...          1.0
# 2            Kenya        2003   KE2003DHS    ED_LITR_W_RDW  ...          1.0
# 3            Kenya        2003   KE2003DHS    ED_LITR_W_RDP  ...          1.0
# 4            Kenya        2003   KE2003DHS    ED_LITR_W_NRD  ...          1.0
# ..             ...         ...         ...              ...  ...          ...
# 99           Kenya        2022   KE2022DHS    ED_LITR_M_BLD  ...          1.0
# 100          Kenya        2022   KE2022DHS    ED_LITR_M_TOT  ...          1.0
# 101          Kenya        2022   KE2022DHS    ED_LITR_M_LIT  ...          1.0
# 102          Kenya        2022   KE2022DHS    ED_LITR_M_NUM  ...          1.0
# 103          Kenya        2022   KE2022DHS    ED_LITR_M_UNW  ...          1.0
#
#           SDRID  RegionId  SurveyYearLabel SurveyType DenominatorWeighted  \
# 0           NaN       NaN              NaN        NaN                 NaN
# 1    EDLITRWSCH       NaN             2003        DHS              8195.0
# 2    EDLITRWRDW       NaN             2003        DHS              8195.0
# 3    EDLITRWRDP       NaN             2003        DHS              8195.0
# 4    EDLITRWNRD       NaN             2003        DHS              8195.0
# ..          ...       ...              ...        ...                 ...
# 99   EDLITRMBLD       NaN             2022        DHS             13652.0
# 100  EDLITRMTOT       NaN             2022        DHS             13652.0
# 101  EDLITRMLIT       NaN             2022        DHS             13652.0
# 102  EDLITRMNUM       NaN             2022        DHS                 NaN
# 103  EDLITRMUNW       NaN             2022        DHS             13652.0
#
#     DenominatorUnweighted CILow  CIHigh  LevelRank
# 0                     NaN   NaN     NaN        NaN
# 1                  8195.0   NaN     NaN        NaN
# 2                  8195.0   NaN     NaN        NaN
# 3                  8195.0   NaN     NaN        NaN
# 4                  8195.0   NaN     NaN        NaN
# ..                    ...   ...     ...        ...
# 99                13669.0   NaN     NaN        NaN
# 100               13669.0   NaN     NaN        NaN
# 101               13669.0   NaN     NaN        NaN
# 102               13669.0   NaN     NaN        NaN
# 103                   NaN   NaN     NaN        NaN
#
# [104 rows x 29 columns]

# %%
# Show the first five rows of the dataset
df.head()
# Out:
#             ISO3    DataId                                 Indicator  \
# 0  #country+code  #meta+id                           #indicator+name
# 1            KEN    419826  Women with secondary or higher education
# 2            KEN    419827       Women who can read a whole sentence
# 3            KEN    419828     Women who can read part of a sentence
# 4            KEN    419833              Women who cannot read at all
#
#                   Value             Precision DHS_CountryCode    CountryName  \
# 0  #indicator+value+num  #indicator+precision             NaN  #country+name
# 1                  29.3                     1              KE          Kenya
# 2                  42.1                     1              KE          Kenya
# 3                   7.1                     1              KE          Kenya
# 4                  21.2                     1              KE          Kenya
#
#    SurveyYear    SurveyId      IndicatorId  ...  IsPreferred       SDRID  \
# 0  #date+year  #survey+id  #indicator+code  ...          NaN         NaN
# 1        2003   KE2003DHS    ED_LITR_W_SCH  ...          1.0  EDLITRWSCH
# 2        2003   KE2003DHS    ED_LITR_W_RDW  ...          1.0  EDLITRWRDW
# 3        2003   KE2003DHS    ED_LITR_W_RDP  ...          1.0  EDLITRWRDP
# 4        2003   KE2003DHS    ED_LITR_W_NRD  ...          1.0  EDLITRWNRD
#
#    RegionId  SurveyYearLabel SurveyType DenominatorWeighted  \
# 0       NaN              NaN        NaN                 NaN
# 1       NaN             2003        DHS              8195.0
# 2       NaN             2003        DHS              8195.0
# 3       NaN             2003        DHS              8195.0
# 4       NaN             2003        DHS              8195.0
#
#   DenominatorUnweighted CILow  CIHigh  LevelRank
# 0                   NaN   NaN     NaN        NaN
# 1                8195.0   NaN     NaN        NaN
# 2                8195.0   NaN     NaN        NaN
# 3                8195.0   NaN     NaN        NaN
# 4                8195.0   NaN     NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Show the last five rows in the dataset
df.tail()
# Out:
#     ISO3  DataId                            Indicator  Value Precision  \
# 99   KEN  230750  Men who are blind/visually impaired      0         1
# 100  KEN  230757                Men's literacy: Total    100         1
# 101  KEN  230753                 Men who are literate   93.8         1
# 102  KEN  150861                        Number of men  13652         0
# 103  KEN  230808           Number of men (unweighted)  13669         0
#
#     DHS_CountryCode CountryName SurveyYear   SurveyId    IndicatorId  ...  \
# 99               KE       Kenya       2022  KE2022DHS  ED_LITR_M_BLD  ...
# 100              KE       Kenya       2022  KE2022DHS  ED_LITR_M_TOT  ...
# 101              KE       Kenya       2022  KE2022DHS  ED_LITR_M_LIT  ...
# 102              KE       Kenya       2022  KE2022DHS  ED_LITR_M_NUM  ...
# 103              KE       Kenya       2022  KE2022DHS  ED_LITR_M_UNW  ...
#
#      IsPreferred       SDRID  RegionId  SurveyYearLabel SurveyType  \
# 99           1.0  EDLITRMBLD       NaN             2022        DHS
# 100          1.0  EDLITRMTOT       NaN             2022        DHS
# 101          1.0  EDLITRMLIT       NaN             2022        DHS
# 102          1.0  EDLITRMNUM       NaN             2022        DHS
# 103          1.0  EDLITRMUNW       NaN             2022        DHS
#
#     DenominatorWeighted DenominatorUnweighted CILow  CIHigh  LevelRank
# 99              13652.0               13669.0   NaN     NaN        NaN
# 100             13652.0               13669.0   NaN     NaN        NaN
# 101             13652.0               13669.0   NaN     NaN        NaN
# 102                 NaN               13669.0   NaN     NaN        NaN
# 103             13652.0                   NaN   NaN     NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Determine the number of rows and columns
df.shape
# Out:
# (104, 29)

# %%
# What columns are in the dataset
df.columns
# Out:
# Index(['ISO3', 'DataId', 'Indicator', 'Value', 'Precision', 'DHS_CountryCode',
#        'CountryName', 'SurveyYear', 'SurveyId', 'IndicatorId',
#        'IndicatorOrder', 'IndicatorType', 'CharacteristicId',
#        'CharacteristicOrder', 'CharacteristicCategory', 'CharacteristicLabel',
#        'ByVariableId', 'ByVariableLabel', 'IsTotal', 'IsPreferred', 'SDRID',
#        'RegionId', 'SurveyYearLabel', 'SurveyType', 'DenominatorWeighted',
#        'DenominatorUnweighted', 'CILow', 'CIHigh', 'LevelRank'],
#       dtype='object')

# %%
# Determine the types of data of each columns
df.dtypes
# Out:
# ISO3                       object
# DataId                     object
# Indicator                  object
# Value                      object
# Precision                  object
# DHS_CountryCode            object
# CountryName                object
# SurveyYear                 object
# SurveyId                   object
# IndicatorId                object
# IndicatorOrder            float64
# IndicatorType              object
# CharacteristicId          float64
# CharacteristicOrder       float64
# CharacteristicCategory     object
# CharacteristicLabel        object
# ByVariableId               object
# ByVariableLabel            object
# IsTotal                   float64
# IsPreferred               float64
# SDRID                      object
# RegionId                  float64
# SurveyYearLabel            object
# SurveyType                 object
# DenominatorWeighted       float64
# DenominatorUnweighted     float64
# CILow                     float64
# CIHigh                    float64
# LevelRank                 float64
# dtype: object

# %%
# Get the summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ISO3                    104 non-null    object
#  1   DataId                  104 non-null    object
#  2   Indicator               104 non-null    object
#  3   Value                   104 non-null    object
#  4   Precision               104 non-null    object
#  5   DHS_CountryCode         103 non-null    object
#  6   CountryName             104 non-null    object
#  7   SurveyYear              104 non-null    object
#  8   SurveyId                104 non-null    object
#  9   IndicatorId             104 non-null    object
#  10  IndicatorOrder          103 non-null    float64
#  11  IndicatorType           103 non-null    object
#  12  CharacteristicId        103 non-null    float64
#  13  CharacteristicOrder     103 non-null    float64
#  14  CharacteristicCategory  103 non-null    object
#  15  CharacteristicLabel     103 non-null    object
#  16  ByVariableId            104 non-null    object
#  17  ByVariableLabel         1 non-null      object
#  18  IsTotal                 103 non-null    float64
#  19  IsPreferred             103 non-null    float64
#  20  SDRID                   103 non-null    object
#  21  RegionId                0 non-null      float64
#  22  SurveyYearLabel         103 non-null    object
#  23  SurveyType              103 non-null    object
#  24  DenominatorWeighted     93 non-null     float64
#  25  DenominatorUnweighted   93 non-null     float64
#  26  CILow                   0 non-null      float64
#  27  CIHigh                  0 non-null      float64
#  28  LevelRank               0 non-null      float64
# dtypes: float64(11), object(18)
# memory usage: 23.7+ KB

# %% [markdown]
# ## Handle duplicates

# %%
# Drop the duplicates in the dataset
df.drop_duplicates()
# Out:
#               ISO3    DataId                                 Indicator  \
# 0    #country+code  #meta+id                           #indicator+name
# 1              KEN    419826  Women with secondary or higher education
# 2              KEN    419827       Women who can read a whole sentence
# 3              KEN    419828     Women who can read part of a sentence
# 4              KEN    419833              Women who cannot read at all
# ..             ...       ...                                       ...
# 99             KEN    230750       Men who are blind/visually impaired
# 100            KEN    230757                     Men's literacy: Total
# 101            KEN    230753                      Men who are literate
# 102            KEN    150861                             Number of men
# 103            KEN    230808                Number of men (unweighted)
#
#                     Value             Precision DHS_CountryCode  \
# 0    #indicator+value+num  #indicator+precision             NaN
# 1                    29.3                     1              KE
# 2                    42.1                     1              KE
# 3                     7.1                     1              KE
# 4                    21.2                     1              KE
# ..                    ...                   ...             ...
# 99                      0                     1              KE
# 100                   100                     1              KE
# 101                  93.8                     1              KE
# 102                 13652                     0              KE
# 103                 13669                     0              KE
#
#        CountryName  SurveyYear    SurveyId      IndicatorId  ...  IsPreferred  \
# 0    #country+name  #date+year  #survey+id  #indicator+code  ...          NaN
# 1            Kenya        2003   KE2003DHS    ED_LITR_W_SCH  ...          1.0
# 2            Kenya        2003   KE2003DHS    ED_LITR_W_RDW  ...          1.0
# 3            Kenya        2003   KE2003DHS    ED_LITR_W_RDP  ...          1.0
# 4            Kenya        2003   KE2003DHS    ED_LITR_W_NRD  ...          1.0
# ..             ...         ...         ...              ...  ...          ...
# 99           Kenya        2022   KE2022DHS    ED_LITR_M_BLD  ...          1.0
# 100          Kenya        2022   KE2022DHS    ED_LITR_M_TOT  ...          1.0
# 101          Kenya        2022   KE2022DHS    ED_LITR_M_LIT  ...          1.0
# 102          Kenya        2022   KE2022DHS    ED_LITR_M_NUM  ...          1.0
# 103          Kenya        2022   KE2022DHS    ED_LITR_M_UNW  ...          1.0
#
#           SDRID  RegionId  SurveyYearLabel SurveyType DenominatorWeighted  \
# 0           NaN       NaN              NaN        NaN                 NaN
# 1    EDLITRWSCH       NaN             2003        DHS              8195.0
# 2    EDLITRWRDW       NaN             2003        DHS              8195.0
# 3    EDLITRWRDP       NaN             2003        DHS              8195.0
# 4    EDLITRWNRD       NaN             2003        DHS              8195.0
# ..          ...       ...              ...        ...                 ...
# 99   EDLITRMBLD       NaN             2022        DHS             13652.0
# 100  EDLITRMTOT       NaN             2022        DHS             13652.0
# 101  EDLITRMLIT       NaN             2022        DHS             13652.0
# 102  EDLITRMNUM       NaN             2022        DHS                 NaN
# 103  EDLITRMUNW       NaN             2022        DHS             13652.0
#
#     DenominatorUnweighted CILow  CIHigh  LevelRank
# 0                     NaN   NaN     NaN        NaN
# 1                  8195.0   NaN     NaN        NaN
# 2                  8195.0   NaN     NaN        NaN
# 3                  8195.0   NaN     NaN        NaN
# 4                  8195.0   NaN     NaN        NaN
# ..                    ...   ...     ...        ...
# 99                13669.0   NaN     NaN        NaN
# 100               13669.0   NaN     NaN        NaN
# 101               13669.0   NaN     NaN        NaN
# 102               13669.0   NaN     NaN        NaN
# 103                   NaN   NaN     NaN        NaN
#
# [104 rows x 29 columns]

# %%
# Confirm if the duplicates were dropped
df.shape
# Out:
# (104, 29)

# %% [markdown]
# ### NOTE: ***There were no duplicates in the dataset***

# %%
# Drop the first row 
df = df.drop(index=0)
df.reset_index(drop=True, inplace=True)

# %%
# Confirm if the first row was removed
print(df.head())
# Out:
#   ISO3  DataId                                          Indicator Value  \
# 0  KEN  419826           Women with secondary or higher education  29.3
# 1  KEN  419827                Women who can read a whole sentence  42.1
# 2  KEN  419828              Women who can read part of a sentence   7.1
# 3  KEN  419833                       Women who cannot read at all  21.2
# 4  KEN  419829  Women for whom no card with required language ...     0
#
#   Precision DHS_CountryCode CountryName SurveyYear   SurveyId    IndicatorId  \
# 0         1              KE       Kenya       2003  KE2003DHS  ED_LITR_W_SCH
# 1         1              KE       Kenya       2003  KE2003DHS  ED_LITR_W_RDW
# 2         1              KE       Kenya       2003  KE2003DHS  ED_LITR_W_RDP
# 3         1              KE       Kenya       2003  KE2003DHS  ED_LITR_W_NRD
# 4         1              KE       Kenya       2003  KE2003DHS  ED_LITR_W_NCD
#
#    ...  IsPreferred       SDRID  RegionId  SurveyYearLabel SurveyType  \
# 0  ...          1.0  EDLITRWSCH       NaN             2003        DHS
# 1  ...          1.0  EDLITRWRDW       NaN             2003        DHS
# 2  ...          1.0  EDLITRWRDP       NaN             2003        DHS
# 3  ...          1.0  EDLITRWNRD       NaN             2003        DHS
# 4  ...          1.0  EDLITRWNCD       NaN             2003        DHS
#
#   DenominatorWeighted DenominatorUnweighted CILow  CIHigh  LevelRank
# 0              8195.0                8195.0   NaN     NaN        NaN
# 1              8195.0                8195.0   NaN     NaN        NaN
# 2              8195.0                8195.0   NaN     NaN        NaN
# 3              8195.0                8195.0   NaN     NaN        NaN
# 4              8195.0                8195.0   NaN     NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Determine the number of missing values in each column
df.isna().sum()
# Out:
# ISO3                        0
# DataId                      0
# Indicator                   0
# Value                       0
# Precision                   0
# DHS_CountryCode             0
# CountryName                 0
# SurveyYear                  0
# SurveyId                    0
# IndicatorId                 0
# IndicatorOrder              0
# IndicatorType               0
# CharacteristicId            0
# CharacteristicOrder         0
# CharacteristicCategory      0
# CharacteristicLabel         0
# ByVariableId                0
# ByVariableLabel           103
# IsTotal                     0
# IsPreferred                 0
# SDRID                       0
# RegionId                  103
# SurveyYearLabel             0
# SurveyType                  0
# DenominatorWeighted        10
# DenominatorUnweighted      10
# CILow                     103
# CIHigh                    103
# LevelRank                 103
# dtype: int64

# %%
# Determine the missing values in each row and column using boolean
df.isna()
# Out:
#       ISO3  DataId  Indicator  Value  Precision  DHS_CountryCode  CountryName  \
# 0    False   False      False  False      False            False        False
# 1    False   False      False  False      False            False        False
# 2    False   False      False  False      False            False        False
# 3    False   False      False  False      False            False        False
# 4    False   False      False  False      False            False        False
# ..     ...     ...        ...    ...        ...              ...          ...
# 98   False   False      False  False      False            False        False
# 99   False   False      False  False      False            False        False
# 100  False   False      False  False      False            False        False
# 101  False   False      False  False      False            False        False
# 102  False   False      False  False      False            False        False
#
#      SurveyYear  SurveyId  IndicatorId  ...  IsPreferred  SDRID  RegionId  \
# 0         False     False        False  ...        False  False      True
# 1         False     False        False  ...        False  False      True
# 2         False     False        False  ...        False  False      True
# 3         False     False        False  ...        False  False      True
# 4         False     False        False  ...        False  False      True
# ..          ...       ...          ...  ...          ...    ...       ...
# 98        False     False        False  ...        False  False      True
# 99        False     False        False  ...        False  False      True
# 100       False     False        False  ...        False  False      True
# 101       False     False        False  ...        False  False      True
# 102       False     False        False  ...        False  False      True
#
#      SurveyYearLabel  SurveyType  DenominatorWeighted  DenominatorUnweighted  \
# 0              False       False                False                  False
# 1              False       False                False                  False
# 2              False       False                False                  False
# 3              False       False                False                  False
# 4              False       False                False                  False
# ..               ...         ...                  ...                    ...
# 98             False       False                False                  False
# 99             False       False                False                  False
# 100            False       False                False                  False
# 101            False       False                 True                  False
# 102            False       False                False                   True
#
#      CILow  CIHigh  LevelRank
# 0     True    True       True
# 1     True    True       True
# 2     True    True       True
# 3     True    True       True
# 4     True    True       True
# ..     ...     ...        ...
# 98    True    True       True
# 99    True    True       True
# 100   True    True       True
# 101   True    True       True
# 102   True    True       True
#
# [103 rows x 29 columns]

# %%
# Drop the columns that have excess missing values
df.drop(columns= ['ByVariableLabel', 'RegionId', 'CILow', 'CIHigh', 'LevelRank'], inplace=True)
df.isna().sum()
# Out:
# ISO3                       0
# DataId                     0
# Indicator                  0
# Value                      0
# Precision                  0
# DHS_CountryCode            0
# CountryName                0
# SurveyYear                 0
# SurveyId                   0
# IndicatorId                0
# IndicatorOrder             0
# IndicatorType              0
# CharacteristicId           0
# CharacteristicOrder        0
# CharacteristicCategory     0
# CharacteristicLabel        0
# ByVariableId               0
# IsTotal                    0
# IsPreferred                0
# SDRID                      0
# SurveyYearLabel            0
# SurveyType                 0
# DenominatorWeighted       10
# DenominatorUnweighted     10
# dtype: int64

# %%
# Impute median to handle missing values in`DenominatorWeighted` 
df['DenominatorWeighted'].fillna(df['DenominatorWeighted'].median(), inplace=True)

# %%
# Impute median to handle missing values in`DenominatorUnweighted` 
df['DenominatorUnweighted'].fillna(df['DenominatorUnweighted'].median(), inplace=True)

# %%
# Confirm if the missing values were handled by checking the number of missing values
df.isna().sum()
# Out:
# ISO3                      0
# DataId                    0
# Indicator                 0
# Value                     0
# Precision                 0
# DHS_CountryCode           0
# CountryName               0
# SurveyYear                0
# SurveyId                  0
# IndicatorId               0
# IndicatorOrder            0
# IndicatorType             0
# CharacteristicId          0
# CharacteristicOrder       0
# CharacteristicCategory    0
# CharacteristicLabel       0
# ByVariableId              0
# IsTotal                   0
# IsPreferred               0
# SDRID                     0
# SurveyYearLabel           0
# SurveyType                0
# DenominatorWeighted       0
# DenominatorUnweighted     0
# dtype: int64

# %%
# Get the summary of dataset after handling the missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ISO3                    103 non-null    object
#  1   DataId                  103 non-null    object
#  2   Indicator               103 non-null    object
#  3   Value                   103 non-null    object
#  4   Precision               103 non-null    object
#  5   DHS_CountryCode         103 non-null    object
#  6   CountryName             103 non-null    object
#  7   SurveyYear              103 non-null    object
#  8   SurveyId                103 non-null    object
#  9   IndicatorId             103 non-null    object
#  10  IndicatorOrder          103 non-null    float64
#  11  IndicatorType           103 non-null    object
#  12  CharacteristicId        103 non-null    float64
#  13  CharacteristicOrder     103 non-null    float64
#  14  CharacteristicCategory  103 non-null    object
#  15  CharacteristicLabel     103 non-null    object
#  16  ByVariableId            103 non-null    object
#  17  IsTotal                 103 non-null    float64
#  18  IsPreferred             103 non-null    float64
#  19  SDRID                   103 non-null    object
#  20  SurveyYearLabel         103 non-null    object
#  21  SurveyType              103 non-null    object
#  22  DenominatorWeighted     103 non-null    float64
#  23  DenominatorUnweighted   103 non-null    float64
# dtypes: float64(7), object(17)
# memory usage: 19.4+ KB

# %% [markdown]
# ## Handle outliers

# %%
# Select only numerical columns
numerical_df = df.select_dtypes(include='number')

# Plot boxplots for each numerical column
numerical_df.plot(kind='box', subplots=True, layout=(len(numerical_df.columns), 1), figsize=(8, 5 * len(numerical_df.columns)))
plt.tight_layout()
plt.show()

# %%
# Handling outliers in `Denominatorweighted` and `DenominatorUnweighted` using the IQR method

columns = ['DenominatorWeighted', 'DenominatorUnweighted']

for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    Q1 = df[col].quantile(0.25)  # 25th percentile
    Q3 = df[col].quantile(0.75)  # 75th percentile
    
    IQR = Q3 - Q1 # Interquantile Range

    lower_bound = Q1 - 1.5 * IQR 
    upper_bound = Q3 + 1.5 * IQR

    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

# %%
# Select and clean relevant columns
columns = ['DenominatorWeighted', 'DenominatorUnweighted']
data = df[columns].dropna()

# plot boxplots to confirm if the outliers were removed
plt.boxplot([data[col] for col in columns], labels=columns)
plt.title("Boxplot of Denominator Counts")
plt.ylabel("Count")
plt.show()

# %%
# Save the cleaned dataset to a new variable
df_cleaned = df.copy()

# %%
# Recheck the summary of the dataframe after cleaning
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ISO3                    103 non-null    object
#  1   DataId                  103 non-null    object
#  2   Indicator               103 non-null    object
#  3   Value                   103 non-null    object
#  4   Precision               103 non-null    object
#  5   DHS_CountryCode         103 non-null    object
#  6   CountryName             103 non-null    object
#  7   SurveyYear              103 non-null    object
#  8   SurveyId                103 non-null    object
#  9   IndicatorId             103 non-null    object
#  10  IndicatorOrder          103 non-null    float64
#  11  IndicatorType           103 non-null    object
#  12  CharacteristicId        103 non-null    float64
#  13  CharacteristicOrder     103 non-null    float64
#  14  CharacteristicCategory  103 non-null    object
#  15  CharacteristicLabel     103 non-null    object
#  16  ByVariableId            103 non-null    object
#  17  IsTotal                 103 non-null    float64
#  18  IsPreferred             103 non-null    float64
#  19  SDRID                   103 non-null    object
#  20  SurveyYearLabel         103 non-null    object
#  21  SurveyType              103 non-null    object
#  22  DenominatorWeighted     103 non-null    float64
#  23  DenominatorUnweighted   103 non-null    float64
# dtypes: float64(7), object(17)
# memory usage: 19.4+ KB

# %%
# Recheck the number of rows and columns after cleaning
df_cleaned.shape
# Out:
# (103, 24)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_cleaned.describe()
# Out:
#        IndicatorOrder  CharacteristicId  CharacteristicOrder  IsTotal  \
# count    1.030000e+02             103.0                103.0    103.0
# mean     2.312335e+08           10000.0              10000.0      1.0
# std      5.491655e+02               0.0                  0.0      0.0
# min      2.312330e+08           10000.0              10000.0      1.0
# 25%      2.312330e+08           10000.0              10000.0      1.0
# 50%      2.312331e+08           10000.0              10000.0      1.0
# 75%      2.312342e+08           10000.0              10000.0      1.0
# max      2.312342e+08           10000.0              10000.0      1.0
#
#        IsPreferred  DenominatorWeighted  DenominatorUnweighted
# count        103.0           103.000000             103.000000
# mean           1.0         11143.805825           11146.868932
# std            0.0          7738.292128            7754.998104
# min            1.0          3258.000000            3256.000000
# 25%            1.0          5394.000000            5394.000000
# 50%            1.0          8444.000000            8444.000000
# 75%            1.0         13652.000000           13669.000000
# max            1.0         26039.000000           26081.500000

# %%
# Histogram of Literacy Rates (Value)
plt.figure(figsize=(8, 6))
plt.hist(df_cleaned['Value'], bins=30, edgecolor='black', color='skyblue', alpha=0.7)
plt.title('Distribution of Literacy Rate (Value)')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Frequency')
xticks = np.arange(0, 101, 10)
plt.xticks(xticks)
plt.tight_layout()
plt.show()

# %%
# Scatterplot of Literacy Rate Over Time
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='SurveyYear', y='Value')
plt.title('Literacy Rate Over Time by Gender')
plt.xlabel('SurveyYear')
plt.ylabel('Literacy Rate (%)')
yticks = np.arange(0, 101, 10)
plt.yticks(yticks)
plt.tight_layout()
plt.show()

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ISO3                    103 non-null    object
#  1   DataId                  103 non-null    object
#  2   Indicator               103 non-null    object
#  3   Value                   103 non-null    object
#  4   Precision               103 non-null    object
#  5   DHS_CountryCode         103 non-null    object
#  6   CountryName             103 non-null    object
#  7   SurveyYear              103 non-null    object
#  8   SurveyId                103 non-null    object
#  9   IndicatorId             103 non-null    object
#  10  IndicatorOrder          103 non-null    float64
#  11  IndicatorType           103 non-null    object
#  12  CharacteristicId        103 non-null    float64
#  13  CharacteristicOrder     103 non-null    float64
#  14  CharacteristicCategory  103 non-null    object
#  15  CharacteristicLabel     103 non-null    object
#  16  ByVariableId            103 non-null    object
#  17  IsTotal                 103 non-null    float64
#  18  IsPreferred             103 non-null    float64
#  19  SDRID                   103 non-null    object
#  20  SurveyYearLabel         103 non-null    object
#  21  SurveyType              103 non-null    object
#  22  DenominatorWeighted     103 non-null    float64
#  23  DenominatorUnweighted   103 non-null    float64
# dtypes: float64(7), object(17)
# memory usage: 19.4+ KB

# %%
# Bar chart for 'Indicator'
plt.figure(figsize=(12, 6))
df_cleaned["Indicator"].value_counts().plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Frequency of Indicators")
plt.xlabel("Indicator")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
# Heatmap of Correlation Matrix
numeric_cols = ['DenominatorWeighted', 'DenominatorUnweighted']
corr_matrix = df_cleaned[numeric_cols].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### 1. **Create percentage column**

# %%
df_cleaned['Value'] = pd.to_numeric(df_cleaned['Value'], errors='coerce')
df_cleaned['LiteracyRatePercent'] = df_cleaned['Value']
df_cleaned['LiteracyRatePercent']
# Out:
# 0         29.3
# 1         42.1
# 2          7.1
# 3         21.2
# 4          0.0
#         ...
# 98         0.0
# 99       100.0
# 100       93.8
# 101    13652.0
# 102    13669.0
# Name: LiteracyRatePercent, Length: 103, dtype: float64

# %% [markdown]
# ### 2. **Create ratio features**

# %%
# Create the ratio for weighted
df_cleaned['WeightedRatio'] = df_cleaned['Value'] / df_cleaned['DenominatorWeighted']
df_cleaned['WeightedRatio']
# Out:
# 0      0.003575
# 1      0.005137
# 2      0.000866
# 3      0.002587
# 4      0.000000
#          ...
# 98     0.000000
# 99     0.007325
# 100    0.006871
# 101    1.616769
# 102    1.001245
# Name: WeightedRatio, Length: 103, dtype: float64

# %%
# Create the ratio for Unweigted
df_cleaned['UnweightedRatio'] = df_cleaned['Value'] / df_cleaned['DenominatorUnweighted']
df_cleaned['UnweightedRatio']
# Out:
# 0      0.003575
# 1      0.005137
# 2      0.000866
# 3      0.002587
# 4      0.000000
#          ...
# 98     0.000000
# 99     0.007316
# 100    0.006862
# 101    0.998756
# 102    1.618783
# Name: UnweightedRatio, Length: 103, dtype: float64

# %%
# Check the columns in the cleaned dataset to see if the new columns were created
df_cleaned.columns
# Out:
# Index(['ISO3', 'DataId', 'Indicator', 'Value', 'Precision', 'DHS_CountryCode',
#        'CountryName', 'SurveyYear', 'SurveyId', 'IndicatorId',
#        'IndicatorOrder', 'IndicatorType', 'CharacteristicId',
#        'CharacteristicOrder', 'CharacteristicCategory', 'CharacteristicLabel',
#        'ByVariableId', 'IsTotal', 'IsPreferred', 'SDRID', 'SurveyYearLabel',
#        'SurveyType', 'DenominatorWeighted', 'DenominatorUnweighted',
#        'LiteracyRatePercent', 'WeightedRatio', 'UnweightedRatio'],
#       dtype='object')

# %% [markdown]
# ## Conclusion
# This analysis reveals steady progress in literacy rates, with disparities across gender and education levels. By leveraging DHS and MIS survey data, a Tableau dashboard has been built to visualize trends, gaps, and performance. The findings offer a data-driven foundation for educational planning.
#
# ## Summary of Key Findings
# 1. There are gender disparities, with women consistently reporting lower literacy and education levels than men.
# 2. Literacy rates have improved across both genders, especially in younger age groups.
# 3. Survey sample sizes vary, influencing the reliability of certain indicators.
# 4. Education access (secondary) remains limited, especially for women.
#
# ## Implications
# Targeted literacy programs for women and regions are essential, as future surveys should ensure consistent sample sizes. The dashboard can be used to monitor the impact of literacy interventions over time. Insights can support funding decisions for education initiatives.
#
# ## Limitations
# The dataset lacks regional, rural, and county-level granularity. Some indicators may be similar, requiring careful grouping. Variations in sample size may affect trend interpretation.
#
# ## Future Work
# Incorporate rural, regional, and county-level data for insights. Connect literacy indicators to employment and health metrics. Use machine learning to forecast literacy trends or identify high-risk groups.

# %% [markdown]
# ## Reference

# %% [markdown]
# # ***data.Humdata.org***
#
# **(https://data.humdata.org/dataset/dhs-data-for-kenya?force_layout=desktop)**

# %%
output_file_path = 'Cleaned_literacy_national_ken.csv'
df_cleaned.to_csv(output_file_path, index=False)

print("Data saved successfully as Cleaned_literacy_national_ken.csv")
# Out:
# Data saved successfully as Cleaned_literacy_national_ken.csv
